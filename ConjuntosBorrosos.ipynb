# %% [markdown]
# <a href="https://colab.research.google.com/github/wmiguel29/IA_Optativa/blob/main/ConjuntosBorrosos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 993 kB 4.8 MB/s
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894089 sha256=efcc5a761e0b59290f86717c627d13f51e924b8bf604d1beecfb0d1c2edc287c
#   Stored in directory: /root/.cache/pip/wheels/d5/74/fc/38588a3d2e3f34f74588e6daa3aa5b0a322bd6f9420a707131
# Successfully built scikit-fuzzy
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import skfuzzy as fuzz
import skfuzzy.control as ctrl

# %% [markdown]
# #Conjuntos borrosos y variables linguisticas

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %%
##Se define el Universo en X
x = np.arange(10000,35000,0.1)
mf_t = fuzz.membership.trimf(x,[15000,20000,25000])
plt.plot(x,mf_t)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %%
x = np.arange(0,5,0.1)
mf_tp = fuzz.membership.trapmf(x,[1,2,3,4.5])
plt.plot(x,mf_tp)

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %%
k = np.arange(0,10,0.1)
mf_g = fuzz.membership.gaussmf(k, mean = 5, sigma = 1)
plt.plot(k,mf_g)

# %% [markdown]
# ## Ejemplo

# %%
x = np.arange(0,10,0.1)
plt.figure()
tests = [0.5,1,1.5,2,3]
for i,s in enumerate(tests):
  mf_gbell = fuzz.membership.gaussmf(x,mean = 5,sigma =s)
  plt.plot(x,mf_gbell, label = f'sigma={s}')
plt.legend(loc = "best")

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %%
x = np.arange(0,10,0.1)
plt.figure()
lb = [0.5,1,1.5,2,3]
for i,b in enumerate(lb):
  mf_gbell = fuzz.membership.gbellmf(x,a=2,b=b,c=5)
  plt.plot(x,mf_gbell,label = f'b={b}')
plt.legend(loc ="best")

# %%
x = np.arange(0,10,0.1)
plt.figure()
lc = [0.5,1,1.5,2,3]
for i,c in enumerate(lb):
  mf_gbell = fuzz.membership.gbellmf(x,a=2,b=1,c=c)
  plt.plot(x,mf_gbell,label = f'b={c}')
plt.legend(loc ="best")

# %%
x = np.arange(0,10,0.1)
plt.figure()
la = [0.5,1,1.5,2,3]
for i,a in enumerate(lb):
  mf_gbell = fuzz.membership.gbellmf(x,a=a,b=1,c=5)
  plt.plot(x,mf_gbell,label = f'b={a}')
plt.legend(loc ="best")

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %%
x = np.arange(0,10,0.1)
mf_sig = fuzz.membership.sigmf(x,b=5,c =-2)
plt.plot(x,mf_sig)
